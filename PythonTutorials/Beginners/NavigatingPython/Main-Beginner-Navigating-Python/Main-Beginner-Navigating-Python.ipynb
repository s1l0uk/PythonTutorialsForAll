# %% [markdown]
# # Navigating Python
#
#
# ## Chapters
#
# 1. Exploring Python
#   * [Exploring Python Objects](https://colab.research.google.com/github/s1l0uk/test_repo/blob/feature_AddingMo4rContent/PythonTutorials/Beginners/NavigatingPython/ExploringPythonObjects/ExploringPythonObjects.ipynb)
# 2. Logging Tutorial
#   * [Log All The Things](https://colab.research.google.com/github/s1l0uk/test_repo/blob/feature_AddingMo4rContent/PythonTutorials/Beginners/NavigatingPython/LogAllTheThings/LogAllTheThings.ipynb)
